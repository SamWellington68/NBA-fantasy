# %%
import pandas as pd 
import csv
data= pd.read_csv('inst126basketballstats1.csv')
adp=pd.read_csv('adpfix.csv')
data.set_index('Player')
adp.set_index('Player')
# Out:
#                    ADP
# Player
# Alberto Abalde  671.40
# Alex Abrines    674.60
# Quincy Acy      677.60
# Jalen Adams     680.60
# Jaylen Adams    681.60
# ...                ...
# Thaddeus Young  127.96
# Trae Young       19.29
# Cody Zeller     142.98
# Ante Zizic      479.94
# Ivica Zubac     151.32
#
# [446 rows x 1 columns]

# %%
for player in data['Player']:
    for name in adp['Player']:
        if player == name:
            print(player,name)
# Out:
# Quincy Acy Quincy Acy
# Jaylen Adams Jaylen Adams
# Steven Adams Steven Adams
# Bam Adebayo Bam Adebayo
# LaMarcus Aldridge LaMarcus Aldridge
# Grayson Allen Grayson Allen
# Jarrett Allen Jarrett Allen
# Al-Farouq Aminu Al-Farouq Aminu
# Justin Anderson Justin Anderson
# Kyle Anderson Kyle Anderson
# Ryan Anderson Ryan Anderson
# Ryan Anderson Ryan Anderson
# Ryan Anderson Ryan Anderson
# Giannis Antetokounmpo Giannis Antetokounmpo
# Kostas Antetokounmpo Kostas Antetokounmpo
# Carmelo Anthony Carmelo Anthony
# OG Anunoby OG Anunoby
# Ryan Arcidiacono Ryan Arcidiacono
# Trevor Ariza Trevor Ariza
# Trevor Ariza Trevor Ariza
# Trevor Ariza Trevor Ariza
# D.J. Augustin D.J. Augustin
# Deandre Ayton Deandre Ayton
# Dwayne Bacon Dwayne Bacon
# Marvin Bagley III Marvin Bagley III
# Lonzo Ball Lonzo Ball
# Mo Bamba Mo Bamba
# J.J. Barea J.J. Barea
# Harrison Barnes Harrison Barnes
# Harrison Barnes Harrison Barnes
# Harrison Barnes Harrison Barnes
# Will Barton Will Barton
# ...

# %%
data['ADP'] = ""
for row in data:
    for rdw in adp:
        if row[1] == rdw[1]:
            #data['ADP']=adp['ADP']
            #print(data['Player'])
            #break
            print(adp['Player'],['ADP'])
        else:
            pass
               # print("false")
# Out:
# 0      Alberto Abalde
# 1        Alex Abrines
# 2          Quincy Acy
# 3         Jalen Adams
# 4        Jaylen Adams
#             ...
# 441    Thaddeus Young
# 442        Trae Young
# 443       Cody Zeller
# 444        Ante Zizic
# 445       Ivica Zubac
# Name: Player, Length: 446, dtype: object ['ADP']
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-57-57458a0e978a> in <module>
#       2 for row in data:
#       3     for rdw in adp:
# ----> 4         if row[1] == rdw[1]:
#       5             #data['ADP']=adp['ADP']
#       6             #print(data['Player'])
#
# IndexError: string index out of range

# %%
data
# Out:
#       Rk        Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...    FT%  \
# 0      1  Álex Abrines  SG   25  OKC  31   2  19.0  1.8   5.1  ...  0.923
# 1      2    Quincy Acy  PF   28  PHO  10   0  12.3  0.4   1.8  ...  0.700
# 2      3  Jaylen Adams  PG   22  ATL  34   1  12.6  1.1   3.2  ...  0.778
# 3      4  Steven Adams   C   25  OKC  80  80  33.4  6.0  10.1  ...  0.500
# 4      5   Bam Adebayo   C   21  MIA  82  28  23.3  3.4   5.9  ...  0.735
# ..   ...           ...  ..  ...  ...  ..  ..   ...  ...   ...  ...    ...
# 703  704  Tyler Zeller   C   29  MEM   4   1  20.5  4.0   7.0  ...  0.778
# 704  705    Ante ?i?i?   C   22  CLE  59  25  18.3  3.1   5.6  ...  0.705
# 705  706   Ivica Zubac   C   21  TOT  59  37  17.6  3.6   6.4  ...  0.802
# 706  707   Ivica Zubac   C   21  LAL  33  12  15.6  3.4   5.8  ...  0.864
# 707  708   Ivica Zubac   C   21  LAC  26  25  20.2  3.8   7.2  ...  0.733
#
#      ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# ...

# %%
adp
# Out:
#              Player     ADP
# 0    Alberto Abalde  671.40
# 1      Alex Abrines  674.60
# 2        Quincy Acy  677.60
# 3       Jalen Adams  680.60
# 4      Jaylen Adams  681.60
# ..              ...     ...
# 441  Thaddeus Young  127.96
# 442      Trae Young   19.29
# 443     Cody Zeller  142.98
# 444      Ante Zizic  479.94
# 445     Ivica Zubac  151.32
#
# [446 rows x 2 columns]

# %%
adp['Player'].loc[2]==data['Player'].loc[1]
# Out:
# True

# %%
#with open('adpfix.csv', mode='r') as infile:
   # reader = csv.reader(infile)
  #  with open('adp_new.csv', mode='w') as outfile:
      #  writer = csv.writer(outfile)
       # mydict = {rows[1]:rows[2] for rows in reader}

# %%
key_cols = ['Player']
data = data.merge(adp[key_cols + ['ADP']], how='outer', on=key_cols)
# Out:
#      Rk                  Player Pos   Age   Tm     G    GS    MP   FG   FGA  \
# 0   1.0            Álex Abrines  SG  25.0  OKC  31.0   2.0  19.0  1.8   5.1
# 1   2.0              Quincy Acy  PF  28.0  PHO  10.0   0.0  12.3  0.4   1.8
# 2   3.0            Jaylen Adams  PG  22.0  ATL  34.0   1.0  12.6  1.1   3.2
# 3   4.0            Steven Adams   C  25.0  OKC  80.0  80.0  33.4  6.0  10.1
# 4   5.0             Bam Adebayo   C  21.0  MIA  82.0  28.0  23.3  3.4   5.9
# 5   6.0               Deng Adel  SF  21.0  CLE  19.0   3.0  10.2  0.6   1.9
# 6   7.0  DeVaughn Akoon-Purcell  SG  25.0  DEN   7.0   0.0   3.1  0.4   1.4
# 7   8.0       LaMarcus Aldridge   C  33.0  SAS  81.0  81.0  33.2  8.4  16.3
# 8   9.0            Rawle Alkins  SG  21.0  CHI  10.0   1.0  12.0  1.3   3.9
# 9  10.0           Grayson Allen  SG  23.0  UTA  38.0   2.0  10.9  1.8   4.7
#
#    ...  STL  BLK  TOV   PF   PTS   ADP_x   ADP_y   ADP_x   ADP_y     ADP
# ...
